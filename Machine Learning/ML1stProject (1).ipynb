# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import accuracy_score

# %%
iris_data = pd.read_csv('/content/drive/MyDrive/ML/IRIS.csv')

# %%
# dimensions (no. of rows & columns)
print(iris_data.shape)
# list of columns/features
print(iris_data.columns)
# peek some data
print(iris_data.head(10))
# statistical summary
print(iris_data.describe())
# Out:
# (150, 5)
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
target = iris_data['species']
# distribution of class labels or categories
print(pd.value_counts(target))
print(iris_data.groupby('species').size())
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64
# <ipython-input-54-d4fa82d5150b>:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   print(pd.value_counts(target))

# %%
seed = 7
train_data, test_data = train_test_split(iris_data, test_size=0.3,
random_state=seed, stratify=target)
# shape of the datasets
print('\nShape of training data :',train_data.shape)
print('\nShape of testing data :',test_data.shape)
# class distribution of the training data
print(pd.value_counts(train_data['species']))
# class distribution of the test data
print(pd.value_counts(test_data['species']))
# Out:
# Shape of training data : (105, 5)
#
# Shape of testing data : (45, 5)
# species
# Iris-versicolor    35
# Iris-setosa        35
# Iris-virginica     35
# Name: count, dtype: int64
# species
# Iris-versicolor    15
# Iris-virginica     15
# Iris-setosa        15
# Name: count, dtype: int64
# <ipython-input-55-faa06b70b073>:8: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   print(pd.value_counts(train_data['species']))
# <ipython-input-55-faa06b70b073>:10: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   print(pd.value_counts(test_data['species']))

# %%
train_x = train_data.drop(columns=['species'],axis=1)
train_y = train_data['species']
# separate the independent and target variables from test data
test_x = test_data.drop(columns=['species'],axis=1)
test_y = test_data['species']
# print(train_x)
# print(train_y)
# print(test_x)
# print(test_y)

# %%
model=tree.DecisionTreeClassifier()
# train the model with fit function
model.fit(train_x, train_y)
# Out:
# DecisionTreeClassifier()

# %%
predictions_train = model.predict(train_x)
train_1=accuracy_score(train_y,predictions_train)*100
print('\nTraining Accuracy :', accuracy_score(train_y,predictions_train))
predictions_test = model.predict(test_x)
test_1=accuracy_score(test_y, predictions_test)*100
print('\nTest Accuracy :', accuracy_score(test_y, predictions_test))
# Out:
# Training Accuracy : 1.0
#
# Test Accuracy : 0.9777777777777777

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
model = LogisticRegression(multi_class='ovr', solver='lbfgs', max_iter=300)
model.fit(train_x, train_y)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=300, multi_class='ovr')

# %%
predictions_train = model.predict(train_x)
train_2=accuracy_score(train_y,predictions_train)*100
print('\nTraining Accuracy :', accuracy_score(train_y,predictions_train))
predictions_test = model.predict(test_x)
test_2=accuracy_score(test_y, predictions_test)*100
print('\nTest Accuracy :', accuracy_score(test_y, predictions_test))
# Out:
# Training Accuracy : 0.9523809523809523
#
# Test Accuracy : 0.9333333333333333

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
model = KNeighborsClassifier(n_neighbors=5, metric='euclidean')
model.fit(train_x, train_y)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
predictions_train = model.predict(train_x)
train_3=accuracy_score(train_y,predictions_train)*100
print('\nTraining Accuracy :', accuracy_score(train_y,predictions_train))
predictions_test = model.predict(test_x)
test_3=accuracy_score(test_y, predictions_test)*100
print('\nTest Accuracy :', accuracy_score(test_y, predictions_test))
# Out:
# Training Accuracy : 0.9809523809523809
#
# Test Accuracy : 0.9555555555555556

# %%
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
model = SVC(kernel='rbf', C=1.0, gamma='scale')
model.fit(train_x, train_y)
# Out:
# SVC()

# %%
predictions_train = model.predict(train_x)
train_4=accuracy_score(train_y,predictions_train)*100
print('\nTraining Accuracy :', accuracy_score(train_y,predictions_train))
predictions_test = model.predict(test_x)
test_4=accuracy_score(test_y, predictions_test)*100
print('\nTest Accuracy :', accuracy_score(test_y, predictions_test))
# Out:
# Training Accuracy : 0.9619047619047619
#
# Test Accuracy : 0.9111111111111111

# %%
import pandas as pd
data = {
    "Training Accuracy": [f"{train_1:.2f}%", f"{train_2:.2f}%", f"{train_3:.2f}%", f"{train_4:.2f}%"],
    "Test Accuracy": [f"{test_1:.2f}%", f"{test_2:.2f}%", f"{test_3:.2f}%", f"{test_4:.2f}%"]
}
index_labels = ["DT", "LR", "KNN","SVM"]
df = pd.DataFrame(data, index_labels)
print(df)
# Out:
#     Training Accuracy Test Accuracy
# DT            100.00%        97.78%
# LR             95.24%        93.33%
# KNN            98.10%        95.56%
# SVM            96.19%        91.11%
